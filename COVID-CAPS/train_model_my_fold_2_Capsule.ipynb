# %%
from tensorflow.python.client import device_lib

def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print(get_available_devices())
# Out:
# ['/device:CPU:0', '/device:XLA_CPU:0', '/device:XLA_GPU:0', '/device:XLA_GPU:1', '/device:GPU:0', '/device:GPU:1']

# %%
import tensorflow as tf
tf.test.is_gpu_available()
#tf.test.is_built_with_cuda()
# Out:
# WARNING:tensorflow:From <ipython-input-2-2b33e0c992cb>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import argparse
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from imutils import paths
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

from Capsule_net_modified import get_model
from utils import Metrics

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
DATA_DIR = '/tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/data/cross_validation'
MODEL_DIR = '/tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule'
FOLD = 2
LR = 1e-4
EPOCHS = 50
BATCH_SIZE = 32
TRAINABLE_BASE_LAYERS = 2
IMG_WIDTH, IMG_HEIGHT = (224,224)

# %%
model_name = 'pocus_fold_{0}'
plot_path = 'pocus_fold_{0}'

if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print('Loading images...')
imagePaths = list(paths.list_images(DATA_DIR))
data = []
labels = []

print('Model is called : {model_name_capsule}')
print('selected fold: {FOLD}')

train_labels, test_labels = [], []
train_data, test_data = [], []
# Out:
# Loading images...
# Model is called : {model_name_capsule}
# selected fold: {FOLD}

# %%
for imagePath in imagePaths:
    path_parts = imagePath.split(os.path.sep)
    # extract the split
    train_test = path_parts[-3][-1]
    # extract the class label from the filename
    label = path_parts[-2]
    # load the image, swap color channels, and resize it to be a fixed
    # 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT))

    # update the data and labels lists, respectively
    if train_test == str(FOLD):
        test_labels.append(label)
        test_data.append(image)
    else:
        train_labels.append(label)
        train_data.append(image)

# Prepare data for model
print(
    '\nNumber of training samples: len(train_labels) \n'
    'Number of testing samples: len(test_labels)'
)
# Out:
# Number of training samples: len(train_labels)
# Number of testing samples: len(test_labels)

# %%
len(test_labels)
# Out:
# 470

# %%
assert len(set(train_labels)) == len(set(test_labels)), (
    'Something went wrong. Some classes are only in train or test data.'
)  # yapf: disable

# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 255]
train_data = np.array(train_data) / 255.0
test_data = np.array(test_data) / 255.0
train_labels_text = np.array(train_labels)
test_labels_text = np.array(test_labels)

num_classes = len(set(train_labels))

# perform one-hot encoding on the labels
lb = LabelBinarizer()
lb.fit(train_labels_text)

train_labels = lb.transform(train_labels_text)
test_labels = lb.transform(test_labels_text)

# %%
train_labels_text
# Out:
# array(['covid', 'covid', 'covid', ..., 'regular', 'regular', 'regular'],
#       dtype='<U9')

# %%
#import tensorflow as tf; 
#print(tf.__version__)
#!pip install q keras==2.1.2
#! pip list

# %%
if num_classes == 2:
    train_labels = to_categorical(train_labels, num_classes=num_classes)
    test_labels = to_categorical(test_labels, num_classes=num_classes)

trainX = train_data
trainY = train_labels
testX = test_data
testY = test_labels
print('Class mappings are:', lb.classes_)

# initialize the training data augmentation object
trainAug = ImageDataGenerator(
    rotation_range=10,
    fill_mode='nearest',
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# Load the VGG16 network
model = get_model(
    input_size=(IMG_WIDTH, IMG_HEIGHT, 3), num_classes=num_classes
)
# Out:
# Class mappings are: ['covid' 'pneumonia' 'regular']

# %%
# Number of layers in model head (fresh weights), this is fixed in get_model.
#num_head_layers = 7
# Freeze all VGG layers apart from the last layers (TRAINABLE_BASE_LAYERS)
#num_layers = len(model.layers)
#for ind, layer in enumerate(model.layers):
#    if ind < num_layers - num_head_layers - TRAINABLE_BASE_LAYERS:
#        layer.trainable = False

# Define callbacks
earlyStopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

mcp_save = ModelCheckpoint(
    os.path.join(MODEL_DIR, 'fold_' + str(FOLD) + '_epoch_{epoch:02d}'),
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)
reduce_lr_loss = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=7,
    verbose=1,
    epsilon=1e-4,
    mode='min'
)
# To show balanced accuracy
metrics = Metrics((testX, testY), model)

# compile model
print('Compiling model...')
#opt = Adam(lr=LR, decay=LR / EPOCHS)
opt = Adam(lr=LR, decay = 0)
model.compile(
    loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy']
)

print('Model has {model.count_params()} parameters')
print('Model summary {model.summary()}')
model.summary()
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Compiling model...
# Model has {model.count_params()} parameters
# Model summary {model.summary()}
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 64)    1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, None, 64)    256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 64)    36928
# _________________________________________________________________
# average_pooling2d (AveragePo (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 128)   73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 128)   147584
# _________________________________________________________________
# reshape (Reshape)            (None, None, 128)         0
# _________________________________________________________________
# capsule (Capsule)            (None, 32, 8)             32768
# _________________________________________________________________
# capsule_1 (Capsule)          (None, 32, 8)             2048
# _________________________________________________________________
# capsule_2 (Capsule)          (None, 3, 16)             384
# _________________________________________________________________
# lambda (Lambda)              (None, 3)                 0
# =================================================================
# Total params: 295,616
# Trainable params: 295,488
# Non-trainable params: 128
# _________________________________________________________________

# %%
# train the head of the network
print('Starting training model...')
H = model.fit_generator(
    trainAug.flow(trainX, trainY, batch_size=BATCH_SIZE),
    steps_per_epoch=len(trainX) // BATCH_SIZE,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[earlyStopping, mcp_save, reduce_lr_loss, metrics]
)

# make predictions on the testing set
print('Evaluating network...')
predIdxs = model.predict(testX, batch_size=BATCH_SIZE)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

print('classification report sklearn:')
print(
    classification_report(
        testY.argmax(axis=1), predIdxs, target_names=lb.classes_
    )
)
# Out:
# Starting training model...
# WARNING:tensorflow:From <ipython-input-13-33c78cffd409>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 56 steps, validate on 470 samples
# Epoch 1/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.9585 - accuracy: 0.5897
# Epoch 00001: val_accuracy improved from -inf to 0.61607, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_01
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_01/assets
# Balanced accuracy is: {'val_balanced': 0.3333333333333333}
# 56/56 [==============================] - 27s 479ms/step - loss: 0.9565 - accuracy: 0.5914 - val_loss: 0.8599 - val_accuracy: 0.6161
# Epoch 2/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.9141 - accuracy: 0.6000
# Epoch 00002: val_accuracy did not improve from 0.61607
# Balanced accuracy is: {'val_balanced': 0.21558821528203032}
# 56/56 [==============================] - 20s 366ms/step - loss: 0.9118 - accuracy: 0.6033 - val_loss: 1.0413 - val_accuracy: 0.2679
# Epoch 3/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.8097 - accuracy: 0.6655
# Epoch 00003: val_accuracy did not improve from 0.61607
# Balanced accuracy is: {'val_balanced': 0.3404096074028713}
# 56/56 [==============================] - 20s 363ms/step - loss: 0.8086 - accuracy: 0.6682 - val_loss: 0.8823 - val_accuracy: 0.5491
# Epoch 4/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.7200 - accuracy: 0.7443
# Epoch 00004: val_accuracy did not improve from 0.61607
# Balanced accuracy is: {'val_balanced': 0.3389127032727767}
# 56/56 [==============================] - 20s 359ms/step - loss: 0.7193 - accuracy: 0.7455 - val_loss: 0.9230 - val_accuracy: 0.5000
# Epoch 5/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.6562 - accuracy: 0.7764
# Epoch 00005: val_accuracy did not improve from 0.61607
# Balanced accuracy is: {'val_balanced': 0.38722188201673813}
# 56/56 [==============================] - 20s 357ms/step - loss: 0.6544 - accuracy: 0.7788 - val_loss: 0.8208 - val_accuracy: 0.5893
# Epoch 6/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.6146 - accuracy: 0.8098
# Epoch 00006: val_accuracy did not improve from 0.61607
# Balanced accuracy is: {'val_balanced': 0.3527250459277404}
# 56/56 [==============================] - 20s 350ms/step - loss: 0.6156 - accuracy: 0.8076 - val_loss: 0.9057 - val_accuracy: 0.5045
# Epoch 7/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.5893 - accuracy: 0.8115
# Epoch 00007: val_accuracy improved from 0.61607 to 0.65625, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_07
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_07/assets
# Balanced accuracy is: {'val_balanced': 0.42345376607470914}
# 56/56 [==============================] - 22s 390ms/step - loss: 0.5894 - accuracy: 0.8121 - val_loss: 0.8774 - val_accuracy: 0.6562
# Epoch 8/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.5404 - accuracy: 0.8345
# Epoch 00008: val_accuracy improved from 0.65625 to 0.68304, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_08
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_08/assets
# Balanced accuracy is: {'val_balanced': 0.426549635980132}
# 56/56 [==============================] - 22s 387ms/step - loss: 0.5396 - accuracy: 0.8358 - val_loss: 0.7638 - val_accuracy: 0.6830
# Epoch 9/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.5025 - accuracy: 0.8586
# Epoch 00009: val_accuracy improved from 0.68304 to 0.71429, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_09
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_09/assets
# Balanced accuracy is: {'val_balanced': 0.4502959787711778}
# 56/56 [==============================] - 22s 392ms/step - loss: 0.5008 - accuracy: 0.8606 - val_loss: 0.7395 - val_accuracy: 0.7143
# Epoch 10/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.4308 - accuracy: 0.8955
# Epoch 00010: val_accuracy did not improve from 0.71429
# Balanced accuracy is: {'val_balanced': 0.4372661087296727}
# 56/56 [==============================] - 20s 351ms/step - loss: 0.4379 - accuracy: 0.8939 - val_loss: 0.7577 - val_accuracy: 0.6607
# Epoch 11/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.4116 - accuracy: 0.8920
# Epoch 00011: val_accuracy improved from 0.71429 to 0.74554, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_11
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_11/assets
# Balanced accuracy is: {'val_balanced': 0.5150711029461795}
# 56/56 [==============================] - 22s 389ms/step - loss: 0.4092 - accuracy: 0.8939 - val_loss: 0.6365 - val_accuracy: 0.7455
# Epoch 12/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3451 - accuracy: 0.9322
# Epoch 00012: val_accuracy improved from 0.74554 to 0.79018, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_12
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_12/assets
# Balanced accuracy is: {'val_balanced': 0.534666938831054}
# 56/56 [==============================] - 22s 394ms/step - loss: 0.3437 - accuracy: 0.9328 - val_loss: 0.6215 - val_accuracy: 0.7902
# Epoch 13/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.9494
# Epoch 00013: val_accuracy improved from 0.79018 to 0.82143, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_13
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/capsule/fold_2_epoch_13/assets
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 21s 380ms/step - loss: 0.3017 - accuracy: 0.9475 - val_loss: 0.6084 - val_accuracy: 0.8214
# Epoch 14/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2718 - accuracy: 0.9563
# Epoch 00014: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5056814315846772}
# 56/56 [==============================] - 20s 356ms/step - loss: 0.2721 - accuracy: 0.9560 - val_loss: 0.7782 - val_accuracy: 0.7366
# Epoch 15/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2348 - accuracy: 0.9586
# Epoch 00015: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.498026808192148}
# 56/56 [==============================] - 19s 343ms/step - loss: 0.2344 - accuracy: 0.9588 - val_loss: 0.7388 - val_accuracy: 0.7098
# Epoch 16/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2324 - accuracy: 0.9575
# Epoch 00016: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.49561134925494993}
# 56/56 [==============================] - 19s 338ms/step - loss: 0.2316 - accuracy: 0.9577 - val_loss: 0.8925 - val_accuracy: 0.7054
# Epoch 17/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.9684
# Epoch 00017: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.4593794651969789}
# 56/56 [==============================] - 20s 353ms/step - loss: 0.1859 - accuracy: 0.9690 - val_loss: 0.8310 - val_accuracy: 0.6384
# Epoch 18/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1686 - accuracy: 0.9713
# Epoch 00018: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5173504796897326}
# 56/56 [==============================] - 19s 345ms/step - loss: 0.1680 - accuracy: 0.9718 - val_loss: 0.7946 - val_accuracy: 0.7455
# Epoch 19/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1642 - accuracy: 0.9707
# Epoch 00019: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5056814315846772}
# 56/56 [==============================] - 19s 343ms/step - loss: 0.1642 - accuracy: 0.9707 - val_loss: 0.6940 - val_accuracy: 0.7366
# Epoch 20/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9724
# Epoch 00020: val_accuracy did not improve from 0.82143
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Balanced accuracy is: {'val_balanced': 0.47628767775736547}
# 56/56 [==============================] - 19s 344ms/step - loss: 0.1472 - accuracy: 0.9723 - val_loss: 0.8922 - val_accuracy: 0.6696
# Epoch 21/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.1081 - accuracy: 0.9862
# Epoch 00021: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5101041028781385}
# 56/56 [==============================] - 19s 344ms/step - loss: 0.1080 - accuracy: 0.9859 - val_loss: 0.8242 - val_accuracy: 0.7321
# Epoch 22/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9845
# Epoch 00022: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5076886439409404}
# 56/56 [==============================] - 19s 343ms/step - loss: 0.0991 - accuracy: 0.9848 - val_loss: 0.8219 - val_accuracy: 0.7277
# Epoch 23/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9856
# Epoch 00023: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5076886439409404}
# 56/56 [==============================] - 19s 335ms/step - loss: 0.0967 - accuracy: 0.9859 - val_loss: 0.8290 - val_accuracy: 0.7277
# Epoch 24/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9885
# Epoch 00024: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5076886439409404}
# 56/56 [==============================] - 20s 352ms/step - loss: 0.0930 - accuracy: 0.9881 - val_loss: 0.8026 - val_accuracy: 0.7277
# Epoch 25/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0909 - accuracy: 0.9886
# Epoch 00025: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5173504796897326}
# 56/56 [==============================] - 19s 344ms/step - loss: 0.0912 - accuracy: 0.9888 - val_loss: 0.7831 - val_accuracy: 0.7455
# Epoch 26/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9885
# Epoch 00026: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5149350207525345}
# 56/56 [==============================] - 19s 340ms/step - loss: 0.0890 - accuracy: 0.9881 - val_loss: 0.7996 - val_accuracy: 0.7411
# Epoch 27/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0900 - accuracy: 0.9874
# Epoch 00027: val_accuracy did not improve from 0.82143
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Balanced accuracy is: {'val_balanced': 0.5149350207525345}
# 56/56 [==============================] - 19s 339ms/step - loss: 0.0899 - accuracy: 0.9876 - val_loss: 0.8045 - val_accuracy: 0.7411
# Epoch 28/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9862
# Epoch 00028: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5125195618153365}
# 56/56 [==============================] - 20s 351ms/step - loss: 0.0898 - accuracy: 0.9865 - val_loss: 0.7981 - val_accuracy: 0.7366
# Epoch 29/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9902
# Epoch 00029: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5125195618153365}
# 56/56 [==============================] - 19s 338ms/step - loss: 0.0848 - accuracy: 0.9904 - val_loss: 0.7962 - val_accuracy: 0.7366
# Epoch 30/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9879
# Epoch 00030: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5125195618153365}
# 56/56 [==============================] - 19s 343ms/step - loss: 0.0866 - accuracy: 0.9881 - val_loss: 0.8021 - val_accuracy: 0.7366
# Epoch 31/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9892
# Epoch 00031: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5125195618153365}
# 56/56 [==============================] - 20s 350ms/step - loss: 0.0856 - accuracy: 0.9894 - val_loss: 0.8008 - val_accuracy: 0.7366
# Epoch 32/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9902
# Epoch 00032: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5125195618153365}
# 56/56 [==============================] - 20s 349ms/step - loss: 0.0857 - accuracy: 0.9898 - val_loss: 0.8025 - val_accuracy: 0.7366
# Epoch 33/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9897Restoring model weights from the end of the best epoch.
#
# Epoch 00033: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 346ms/step - loss: 0.0860 - accuracy: 0.9898 - val_loss: 0.8008 - val_accuracy: 0.7366
# Epoch 34/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2688 - accuracy: 0.9460Restoring model weights from the end of the best epoch.
#
# Epoch 00034: val_accuracy did not improve from 0.82143
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 347ms/step - loss: 0.2679 - accuracy: 0.9464 - val_loss: 0.6686 - val_accuracy: 0.7366
# Epoch 35/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3012 - accuracy: 0.9167Restoring model weights from the end of the best epoch.
#
# Epoch 00035: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 347ms/step - loss: 0.2990 - accuracy: 0.9182 - val_loss: 0.6377 - val_accuracy: 0.7545
# Epoch 36/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2981 - accuracy: 0.9218Restoring model weights from the end of the best epoch.
#
# Epoch 00036: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 333ms/step - loss: 0.2990 - accuracy: 0.9216 - val_loss: 0.6382 - val_accuracy: 0.7545
# Epoch 37/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.9190Restoring model weights from the end of the best epoch.
#
# Epoch 00037: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 344ms/step - loss: 0.2982 - accuracy: 0.9182 - val_loss: 0.6368 - val_accuracy: 0.7545
# Epoch 38/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2968 - accuracy: 0.9218Restoring model weights from the end of the best epoch.
#
# Epoch 00038: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 335ms/step - loss: 0.2991 - accuracy: 0.9210 - val_loss: 0.6389 - val_accuracy: 0.7545
# Epoch 39/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2979 - accuracy: 0.9178Restoring model weights from the end of the best epoch.
#
# Epoch 00039: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 339ms/step - loss: 0.2971 - accuracy: 0.9182 - val_loss: 0.6363 - val_accuracy: 0.7545
# Epoch 40/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2998 - accuracy: 0.9161Restoring model weights from the end of the best epoch.
#
# Epoch 00040: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 336ms/step - loss: 0.2989 - accuracy: 0.9165 - val_loss: 0.6376 - val_accuracy: 0.7545
# Epoch 41/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.9178Restoring model weights from the end of the best epoch.
#
# Epoch 00041: val_accuracy did not improve from 0.82143
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 340ms/step - loss: 0.2988 - accuracy: 0.9182 - val_loss: 0.6368 - val_accuracy: 0.7545
# Epoch 42/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3040 - accuracy: 0.9167Restoring model weights from the end of the best epoch.
#
# Epoch 00042: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 343ms/step - loss: 0.3037 - accuracy: 0.9165 - val_loss: 0.6393 - val_accuracy: 0.7545
# Epoch 43/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3082 - accuracy: 0.9132Restoring model weights from the end of the best epoch.
#
# Epoch 00043: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 20s 349ms/step - loss: 0.3066 - accuracy: 0.9142 - val_loss: 0.6419 - val_accuracy: 0.7545
# Epoch 44/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3026 - accuracy: 0.9138Restoring model weights from the end of the best epoch.
#
# Epoch 00044: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 20s 349ms/step - loss: 0.3059 - accuracy: 0.9125 - val_loss: 0.6416 - val_accuracy: 0.7545
# Epoch 45/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3014 - accuracy: 0.9172Restoring model weights from the end of the best epoch.
#
# Epoch 00045: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 343ms/step - loss: 0.3033 - accuracy: 0.9159 - val_loss: 0.6406 - val_accuracy: 0.7545
# Epoch 46/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3039 - accuracy: 0.9121Restoring model weights from the end of the best epoch.
#
# Epoch 00046: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 345ms/step - loss: 0.3060 - accuracy: 0.9114 - val_loss: 0.6397 - val_accuracy: 0.7545
# Epoch 47/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3055 - accuracy: 0.9098Restoring model weights from the end of the best epoch.
#
# Epoch 00047: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 338ms/step - loss: 0.3064 - accuracy: 0.9103 - val_loss: 0.6407 - val_accuracy: 0.7545
# Epoch 48/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3083 - accuracy: 0.9121Restoring model weights from the end of the best epoch.
#
# Epoch 00048: val_accuracy did not improve from 0.82143
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 333ms/step - loss: 0.3079 - accuracy: 0.9120 - val_loss: 0.6411 - val_accuracy: 0.7545
# Epoch 49/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3063 - accuracy: 0.9132Restoring model weights from the end of the best epoch.
#
# Epoch 00049: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 340ms/step - loss: 0.3053 - accuracy: 0.9142 - val_loss: 0.6403 - val_accuracy: 0.7545
# Epoch 50/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.3090 - accuracy: 0.9109Restoring model weights from the end of the best epoch.
#
# Epoch 00050: val_accuracy did not improve from 0.82143
# Balanced accuracy is: {'val_balanced': 0.5538545281349935}
# 56/56 [==============================] - 19s 339ms/step - loss: 0.3099 - accuracy: 0.9103 - val_loss: 0.6414 - val_accuracy: 0.7545
# Epoch 00050: early stopping
# Evaluating network...
# classification report sklearn:
#               precision    recall  f1-score   support
#
#        covid       0.82      0.99      0.90       276
#    pneumonia       0.96      0.68      0.79       142
#      regular       0.00      0.00      0.00        52
#
#     accuracy                           0.78       470
#    macro avg       0.59      0.55      0.56       470
# weighted avg       0.77      0.78      0.77       470

# %%
print('confusion matrix:')
cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)


# serialize the model to disk
#print('Saving COVID-19 detector model on {model_name} data...')
#model.save(os.path.join(MODEL_DIR, model_name), save_format='h5')

# plot the training loss and accuracy
N = EPOCHS
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, N), H.history['loss'], label='train_loss')
plt.plot(np.arange(0, N), H.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, N), H.history['accuracy'], label='train_acc')
plt.plot(np.arange(0, N), H.history['val_accuracy'], label='val_acc')
plt.title('Training Loss and Accuracy on COVID-19 Dataset')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend(loc='lower left')
plt.savefig(os.path.join(MODEL_DIR, plot_path))

print('Done, shuttting down!')
# Out:
# confusion matrix:
# [[272   4   0]
#  [  6  96  40]
#  [ 52   0   0]]
# Done, shuttting down!
