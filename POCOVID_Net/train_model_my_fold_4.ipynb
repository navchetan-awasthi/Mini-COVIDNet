# %%
import argparse
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from imutils import paths
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

from model import get_model
from utils import Metrics

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
DATA_DIR = '/tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/data/cross_validation'
MODEL_DIR = '/tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models'
FOLD = 4
LR = 1e-4
EPOCHS = 20
BATCH_SIZE = 16
TRAINABLE_BASE_LAYERS = 2
IMG_WIDTH, IMG_HEIGHT = (224,224)

# %%
model_name = 'pocus_fold_{0}'
plot_path = 'pocus_fold_{0}'

if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print('Loading images...')
imagePaths = list(paths.list_images(DATA_DIR))
data = []
labels = []

print('Model is called : {model_name}')
print('selected fold: {FOLD}')

train_labels, test_labels = [], []
train_data, test_data = [], []
# Out:
# Loading images...
# Model is called : {model_name}
# selected fold: {FOLD}

# %%
for imagePath in imagePaths:
    path_parts = imagePath.split(os.path.sep)
    # extract the split
    train_test = path_parts[-3][-1]
    # extract the class label from the filename
    label = path_parts[-2]
    # load the image, swap color channels, and resize it to be a fixed
    # 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT))

    # update the data and labels lists, respectively
    if train_test == str(FOLD):
        test_labels.append(label)
        test_data.append(image)
    else:
        train_labels.append(label)
        train_data.append(image)

# Prepare data for model
print(
    '\nNumber of training samples: len(train_labels) \n'
    'Number of testing samples: len(test_labels)'
)
# Out:
# Number of training samples: len(train_labels)
# Number of testing samples: len(test_labels)

# %%
assert len(set(train_labels)) == len(set(test_labels)), (
    'Something went wrong. Some classes are only in train or test data.'
)  # yapf: disable

# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 255]
train_data = np.array(train_data) / 255.0
test_data = np.array(test_data) / 255.0
train_labels_text = np.array(train_labels)
test_labels_text = np.array(test_labels)

num_classes = len(set(train_labels))

# perform one-hot encoding on the labels
lb = LabelBinarizer()
lb.fit(train_labels_text)

train_labels = lb.transform(train_labels_text)
test_labels = lb.transform(test_labels_text)

# %%
if num_classes == 2:
    train_labels = to_categorical(train_labels, num_classes=num_classes)
    test_labels = to_categorical(test_labels, num_classes=num_classes)

trainX = train_data
trainY = train_labels
testX = test_data
testY = test_labels
print('Class mappings are:', lb.classes_)

# initialize the training data augmentation object
trainAug = ImageDataGenerator(
    rotation_range=10,
    fill_mode='nearest',
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# Load the VGG16 network
model = get_model(
    input_size=(IMG_WIDTH, IMG_HEIGHT, 3), num_classes=num_classes
)
# Out:
# Class mappings are: ['covid' 'pneumonia' 'regular']
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 10s 0us/step

# %%
# Number of layers in model head (fresh weights), this is fixed in get_model.
num_head_layers = 7
# Freeze all VGG layers apart from the last layers (TRAINABLE_BASE_LAYERS)
num_layers = len(model.layers)
for ind, layer in enumerate(model.layers):
    if ind < num_layers - num_head_layers - TRAINABLE_BASE_LAYERS:
        layer.trainable = False

# Define callbacks
earlyStopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

mcp_save = ModelCheckpoint(
    os.path.join(MODEL_DIR, 'fold_' + str(FOLD) + '_epoch_{epoch:02d}'),
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)
reduce_lr_loss = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=7,
    verbose=1,
    epsilon=1e-4,
    mode='min'
)
# To show balanced accuracy
metrics = Metrics((testX, testY), model)

# compile model
print('Compiling model...')
opt = Adam(lr=LR, decay=LR / EPOCHS)
model.compile(
    loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy']
)

print('Model has {model.count_params()} parameters')
print('Model summary {model.summary()}')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Compiling model...
# Model has {model.count_params()} parameters
# Model summary {model.summary()}

# %%
# train the head of the network
print('Starting training model...')
H = model.fit_generator(
    trainAug.flow(trainX, trainY, batch_size=BATCH_SIZE),
    steps_per_epoch=len(trainX) // BATCH_SIZE,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[earlyStopping, mcp_save, reduce_lr_loss, metrics]
)

# make predictions on the testing set
print('Evaluating network...')
predIdxs = model.predict(testX, batch_size=BATCH_SIZE)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

print('classification report sklearn:')
print(
    classification_report(
        testY.argmax(axis=1), predIdxs, target_names=lb.classes_
    )
)
# Out:
# Starting training model...
# WARNING:tensorflow:From <ipython-input-8-33c78cffd409>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 117 steps, validate on 398 samples
# Epoch 1/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.6272 - accuracy: 0.7478
# Epoch 00001: val_accuracy improved from -inf to 0.31250, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_01
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_01/assets
# Balanced accuracy is: {'val_balanced': 0.35840188014101054}
# 117/117 [==============================] - 26s 218ms/step - loss: 0.6246 - accuracy: 0.7484 - val_loss: 1.0121 - val_accuracy: 0.3125
# Epoch 2/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.3800 - accuracy: 0.8650
# Epoch 00002: val_accuracy improved from 0.31250 to 0.64062, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_02
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_02/assets
# Balanced accuracy is: {'val_balanced': 0.5433476955216086}
# 117/117 [==============================] - 23s 195ms/step - loss: 0.3790 - accuracy: 0.8656 - val_loss: 0.9045 - val_accuracy: 0.6406
# Epoch 3/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8905
# Epoch 00003: val_accuracy did not improve from 0.64062
# Balanced accuracy is: {'val_balanced': 0.6400872922612052}
# 117/117 [==============================] - 21s 180ms/step - loss: 0.3087 - accuracy: 0.8903 - val_loss: 0.7259 - val_accuracy: 0.6328
# Epoch 4/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.2567 - accuracy: 0.9116
# Epoch 00004: val_accuracy improved from 0.64062 to 0.78646, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_04
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_04/assets
# Balanced accuracy is: {'val_balanced': 0.6231884057971014}
# 117/117 [==============================] - 23s 197ms/step - loss: 0.2564 - accuracy: 0.9118 - val_loss: 0.5993 - val_accuracy: 0.7865
# Epoch 5/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9230
# Epoch 00005: val_accuracy did not improve from 0.78646
# Balanced accuracy is: {'val_balanced': 0.7280323802062932}
# 117/117 [==============================] - 21s 178ms/step - loss: 0.2180 - accuracy: 0.9215 - val_loss: 0.5739 - val_accuracy: 0.7656
# Epoch 6/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.2212 - accuracy: 0.9273
# Epoch 00006: val_accuracy improved from 0.78646 to 0.82031, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_06
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_06/assets
# Balanced accuracy is: {'val_balanced': 0.6972376102810885}
# 117/117 [==============================] - 23s 195ms/step - loss: 0.2201 - accuracy: 0.9280 - val_loss: 0.6407 - val_accuracy: 0.8203
# Epoch 7/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1880 - accuracy: 0.9382
# Epoch 00007: val_accuracy did not improve from 0.82031
# Balanced accuracy is: {'val_balanced': 0.6623953145692276}
# 117/117 [==============================] - 21s 177ms/step - loss: 0.1872 - accuracy: 0.9387 - val_loss: 0.7579 - val_accuracy: 0.7109
# Epoch 8/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1625 - accuracy: 0.9496
# Epoch 00008: val_accuracy improved from 0.82031 to 0.85417, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_08
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_08/assets
# Balanced accuracy is: {'val_balanced': 0.7336093857832987}
# 117/117 [==============================] - 23s 194ms/step - loss: 0.1628 - accuracy: 0.9495 - val_loss: 0.3963 - val_accuracy: 0.8542
# Epoch 9/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1738 - accuracy: 0.9479
# Epoch 00009: val_accuracy did not improve from 0.85417
# Balanced accuracy is: {'val_balanced': 0.747859660903139}
# 117/117 [==============================] - 21s 177ms/step - loss: 0.1741 - accuracy: 0.9478 - val_loss: 0.4171 - val_accuracy: 0.8542
# Epoch 10/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9425
# Epoch 00010: val_accuracy did not improve from 0.85417
# Balanced accuracy is: {'val_balanced': 0.6728032380206294}
# 117/117 [==============================] - 21s 181ms/step - loss: 0.1747 - accuracy: 0.9425 - val_loss: 0.6492 - val_accuracy: 0.7891
# Epoch 11/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1330 - accuracy: 0.9610
# Epoch 00011: val_accuracy did not improve from 0.85417
# Balanced accuracy is: {'val_balanced': 0.6494227146401059}
# 117/117 [==============================] - 20s 171ms/step - loss: 0.1338 - accuracy: 0.9602 - val_loss: 0.6805 - val_accuracy: 0.7005
# Epoch 12/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9593
# Epoch 00012: val_accuracy did not improve from 0.85417
# Balanced accuracy is: {'val_balanced': 0.6806278328017458}
# 117/117 [==============================] - 21s 178ms/step - loss: 0.1391 - accuracy: 0.9597 - val_loss: 0.6285 - val_accuracy: 0.7734
# Epoch 13/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1471 - accuracy: 0.9496
# Epoch 00013: val_accuracy did not improve from 0.85417
# Balanced accuracy is: {'val_balanced': 0.71256038647343}
# 117/117 [==============================] - 21s 176ms/step - loss: 0.1464 - accuracy: 0.9500 - val_loss: 0.4974 - val_accuracy: 0.8359
# Epoch 14/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9637
# Epoch 00014: val_accuracy did not improve from 0.85417
# Balanced accuracy is: {'val_balanced': 0.7263630089717047}
# 117/117 [==============================] - 20s 173ms/step - loss: 0.1198 - accuracy: 0.9629 - val_loss: 0.4996 - val_accuracy: 0.8490
# Epoch 15/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9604
# Epoch 00015: val_accuracy improved from 0.85417 to 0.85677, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_15
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_15/assets
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Balanced accuracy is: {'val_balanced': 0.7422360248447205}
# 117/117 [==============================] - 23s 199ms/step - loss: 0.1301 - accuracy: 0.9608 - val_loss: 0.5378 - val_accuracy: 0.8568
# Epoch 16/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1094 - accuracy: 0.9702
# Epoch 00016: val_accuracy improved from 0.85677 to 0.87240, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_16
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_16/assets
# Balanced accuracy is: {'val_balanced': 0.7739820565907523}
# 117/117 [==============================] - 23s 193ms/step - loss: 0.1087 - accuracy: 0.9704 - val_loss: 0.4032 - val_accuracy: 0.8724
# Epoch 17/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9729
# Epoch 00017: val_accuracy improved from 0.87240 to 0.87760, saving model to /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_17
# INFO:tensorflow:Assets written to: /tf/Modified/covid19_pocus_ultrasound_master/covid19_pocus_ultrasound_master/models/fold_4_epoch_17/assets
# Balanced accuracy is: {'val_balanced': 0.7812284334023465}
# 117/117 [==============================] - 22s 187ms/step - loss: 0.0962 - accuracy: 0.9731 - val_loss: 0.3721 - val_accuracy: 0.8776
# Epoch 18/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.9702
# Epoch 00018: val_accuracy did not improve from 0.87760
# Balanced accuracy is: {'val_balanced': 0.7581090407177363}
# 117/117 [==============================] - 21s 181ms/step - loss: 0.1009 - accuracy: 0.9699 - val_loss: 0.3831 - val_accuracy: 0.8646
# Epoch 19/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.0915 - accuracy: 0.9740
# Epoch 00019: val_accuracy did not improve from 0.87760
# Balanced accuracy is: {'val_balanced': 0.7660455486542442}
# 117/117 [==============================] - 20s 171ms/step - loss: 0.0913 - accuracy: 0.9742 - val_loss: 0.3683 - val_accuracy: 0.8698
# Epoch 20/20
# 116/117 [============================>.] - ETA: 0s - loss: 0.0992 - accuracy: 0.9685
# Epoch 00020: val_accuracy did not improve from 0.87760
# Balanced accuracy is: {'val_balanced': 0.7581090407177363}
# 117/117 [==============================] - 20s 174ms/step - loss: 0.1008 - accuracy: 0.9683 - val_loss: 0.3868 - val_accuracy: 0.8646
# Evaluating network...
# classification report sklearn:
#               precision    recall  f1-score   support
#
#        covid       0.78      1.00      0.88       222
#    pneumonia       1.00      0.87      0.93        92
#      regular       1.00      0.40      0.58        84
#
#     accuracy                           0.84       398
#    macro avg       0.93      0.76      0.79       398
# weighted avg       0.88      0.84      0.83       398

# %%
print('confusion matrix:')
cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)

# serialize the model to disk
print('Saving COVID-19 detector model on {model_name} data...')
model.save(os.path.join(MODEL_DIR, model_name), save_format='h5')

# plot the training loss and accuracy
N = EPOCHS
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, N), H.history['loss'], label='train_loss')
plt.plot(np.arange(0, N), H.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, N), H.history['accuracy'], label='train_acc')
plt.plot(np.arange(0, N), H.history['val_accuracy'], label='val_acc')
plt.title('Training Loss and Accuracy on COVID-19 Dataset')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend(loc='lower left')
plt.savefig(os.path.join(MODEL_DIR, plot_path))

print('Done, shuttting down!')
# Out:
# confusion matrix:
# [[222   0   0]
#  [ 12  80   0]
#  [ 50   0  34]]
# Saving COVID-19 detector model on {model_name} data...
# Done, shuttting down!
